# %%
#importing library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#importing warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Getting the data
df=pd.read_csv("Micro_Credit_Defaulter.csv")

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
#checking the shape of data
df.shape
# Out:
# (209593, 37)

# %%
#There is 209593 rows and 37 columns

# %%
#checking columns
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
#checking data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
#checking the null values
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [raw]
# There is no null values present in the data.

# %% [markdown]
# # Exploring Data Variable

# %%
#Printing their object type and unique code
for column in df.columns:
    if df[column].dtypes==object:
        print(str(column)+  " : "+str(df[column].unique()))
        print(df[column].value_counts())
        print("--------------------------------------------------------------------------------------")
        print("\n")
# Out:
# msisdn : ['21408I70789' '76462I70374' '17943I70372' ... '22758I85348' '59712I82733'
#  '65061I85339']
# 47819I90840    7
# 04581I85330    7
# 94119I84456    6
# 43430I70786    6
# 29191I82738    6
#               ..
# 55084I89238    1
# 67351I95204    1
# 88381I90584    1
# 03168I90845    1
# 25707I82733    1
# Name: msisdn, Length: 186243, dtype: int64
# --------------------------------------------------------------------------------------
#
#
# pcircle : ['UPW']
# UPW    209593
# Name: pcircle, dtype: int64
# --------------------------------------------------------------------------------------
#
#
# pdate : ['7/20/2016' '8/10/2016' '8/19/2016' '6/6/2016' '6/22/2016' '7/2/2016'
#  '7/5/2016' '8/5/2016' '6/15/2016' '6/8/2016' '6/12/2016' '6/20/2016'
#  '6/29/2016' '6/16/2016' '8/3/2016' '6/24/2016' '7/4/2016' '7/3/2016'
#  '7/1/2016' '8/8/2016' '6/26/2016' '6/23/2016' '7/6/2016' '7/9/2016'
#  '6/10/2016' '6/7/2016' '6/27/2016' '8/11/2016' '6/30/2016' '6/19/2016'
# ...

# %% [markdown]
# Observation: Msidn is a mobile number of users.pdate is date.

# %% [markdown]
# # Our Target variable is label which label 1 indicates that loan has been paid and label 0 indicates that  loan has not been paid that is defaulter.

# %% [markdown]
# # 1:sucess 0:failure

# %%
df["label"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [raw]
# 1 is stand for loan has been paid Non-Defaulter, 0 stands for loan has not been paid Defaulter.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755200  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000       209593.00000
# mean     6082.515068    2692.581910    3483.406534         3755.84780
# std     10918.812767    4308.586781    5770.461279        53905.89223
# min       -93.012667  -23737.140000  -24720.580000          -29.00000
# ...

# %% [raw]
# Observation:1]Unnamed columns min is 1 and maximum is 209593 in the Micro_credit_defaulter.The mean is higher than median,standard deviation is on higher side.
# 2]In label the min is 1 0 and maximum is 1
# 3]The age of cellular network  in days min is -48 and maximum is 999860,the mean is higher than median,standard deviation is       also on higher side.
# 4]Daily amount spent from main account,averaged over last 30days(in Indonesian Rupiah) minimum is -93 and maximum is 265926       Rupiah,the mean is higher than median the data has skewness.75th percentile is on higher side,it also have high standard       deviation.
# 5]Daily amount spent from main account,averaged over last 90days(in indonesian Rupiah) minimun is -93 and maximum is 320630       Rupiah,the mean is higher than median ,75ty percentile standard deviation is also higher.
# 6]Average main account balance over last 30days minimum is -23737 and maximum is 198926 Rupiah.The mean,standard devation,75th   percentile is higher than median and 25th percentile.
# 7]Average main account balance over last 90 days minimum is -24720 and maximum is 200148 Rupiah. Mean,75th percentile and         standard deviation is higher than meadian.
# 8]Number of days till last recharge of main account min is -29 and maximum is 998650.The mean is higher than median and           standard deviation is also high.
# 9]Number of days till last recharge of data account min is -29 and maximum is 999171.The mean and standard devation is also       high.
# 10]Amount of last recharge of main account(in Indonesian Rupiah) min is zero and maximum is 55000 Rupiah.
# 11]Number of loan taken in  last 30days min is zero and maximum is 50.
# 12]Total amount of loan taken by users in last 30 days min is maximum is 306.
# 13]maximum amount of loan taken by the users in last 30 days minimum is zero and maximum is 99864 Rupiah.
# 14]Median of amounts of loan taken by the users in last 30days min is zero and maximum is 3.
# 15]Number of loans taken by users in last 90 days min is zero and maximum is 4997 Rupiah.
# 16]Total amount of loan taken by users in last 90 days min is zero and maximum is 438.
# 17]maximum amount of loan taken by the users in last 90days min is zero and maximum is 12.
# 18]Median amounts of loan taken by the users in last 90days min is zero and maximum is 3.
# 19]Average payback time in days over last 30 days min is zero and maximum is 171.50.
# 20]Average payback time in days over last 90 days min is zero and maximum is 171.50

# %% [markdown]
# # Correlation

# %%
corr=df.corr()

# %%
corr
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# ...

# %%
#with help of visiulization
plt.figure(figsize=(20,14))
sns.heatmap(corr,annot=True,fmt=".0%",cmap="Set3")

# %%
#correlation with target variable
plt.figure(figsize=(20,14))
df.drop("label",axis=1).corrwith(df["label"]).plot(kind="bar",grid=True)
plt.xticks(rotation="vertical")
plt.show()

# %% [raw]
# Observation:
#  1] The number of times main account got reacharge in last 30 days and the number of times main account got reacharged in           last90 days has highest positive correaltion with target variable.Daily amount spent from main account, averaged over           last 30 days (in Indonesian Rupiah),Daily amount spent from main account,averaged over last 90 days(in Indonesian               Rupiah),Average main account balance over last 30 days and Average main account balance over last 90 days has                   good positive correlation with target variable.
# 2]  Number of days till last recharge of main account,total amount of reacharge in main account over last 30 days(in Indonesian
#     Rupiah),median of amount of reacharges done in main account over last 30 days at user level (in Indonesian                     Rupiah), total amount of reacharge in main account over last 90days(in Indonesian Rupiah),median amount of reacharge done   in main account over last 90days at user level(in Indonesian Rupiah),median of main acccount balance just before recharge in last 90 days at user level(in Indonesian Rupiah),Number of loan taken by user in last 30 days,total amount of loans taken by users in last 90days, maximum amount of loan taken  by the user in last 90 days,median of amounts of loan taken by the user in last 90 days,Average payback time in days over last 30 days,average payback time in days over last 90 days has good postive bond with target variable that is label.
# 3]  Unnamed,number of days till last reacharge of main account ,number of days till last reacharge of data account,frequency of
#     main account reacharged in last 30 days,number of times data account got reacharged in last 360 days,number of times data
#     account got reacharged in last 90 days,maximum amount of loans taken by users in last 30 days,number of loans taken by         users in last 90 days has low positive bond with target variable.
# 4]  Age on cellular network in days,median of main account balance just before reacharge in last 30 days at user level(in Indon
#     esian Rupiah),frequency of main account reacharge in last 90 days has negative correlation with label.

# %% [markdown]
# As our feature variable is label which label 1 indicates loan has been paid,non-defaulter and 0 indicates loan has not been paid,defaulter.

# %% [markdown]
# # Data Visiulization

# %% [markdown]
# # EDA

# %%
#checking mobile number of users
sns.barplot(x="aon",data=df,palette="Spectral")
plt.title("mobile number of users",fontsize=18)
plt.show()

print(df["aon"].value_counts())
print(df["aon"].unique())
# Out:
# 95.0000        392
# 92.0000        362
# 96.0000        357
# 99.0000        356
# 157.0000       349
#               ...
# 832037.7123      1
# 932056.6019      1
# 890451.7726      1
# 670233.0281      1
# 919992.9709      1
# Name: aon, Length: 4507, dtype: int64
# [2.72000000e+02 7.12000000e+02 5.35000000e+02 ... 8.03380622e+05
#  5.81435484e+05 8.11881373e+05]

# %%
#ploting label 
sns.countplot(x="label",data=df,palette="RdBu_r")
plt.title("Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan")
plt.show()
print(df["label"].value_counts())
print(df["label"].unique())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64
# [0 1]

# %% [raw]
# Observation:
#     Around 183431 thousand people has paid the loan
#     26162 thousand people are defaulter.

# %%
#ploting daily_descr30 by histogram
plt.hist(df["daily_decr30"])
plt.title("Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)",fontsize=18)
plt.show()
print(df["daily_decr30"].unique())
# Out:
# [ 3055.05    12122.       1398.      ... 11843.11167 12488.22833
#   4489.362  ]

# %% [raw]
# observation:Daily amount spent from main account,averaged over last 30 days is 200000 (indonesian Rupiah ).

# %%
#ploting daily_descr90
plt.hist(df["daily_decr90"])
plt.title("Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah",fontsize=18)
plt.show()

# %% [raw]
# observation:
#     Daily amount spent from main account is 200000 (in Indonsian Rupiah).

# %%
plt.hist(x="rental30",data=df)
plt.title("Average main account balance over last 30 days",fontsize=18)
plt.show()

# %% [raw]
# Observation:
#     Average main account balance over last 30 days is 200000(in Indonesian Rupiah)

# %%
#ploting rental90
sns.violinplot(x="rental90",data=df)
plt.title("Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)",fontsize=18)
plt.show()

# %% [raw]
# sns.violinplot(x="last_rech_date_ma",data=df)
# plt.title("Number of days till last recharge of main account")
# plt.show()

# %%
sns.barplot(x="last_rech_date_da",data=df)
plt.title("Number of days till last recharge of data account",fontsize=18)
plt.show()
print(df["last_rech_date_da"].value_counts())
# Out:
# 0.0000         202861
# 7.0000            163
# 8.0000            160
# 11.0000           149
# 13.0000           148
#                 ...
# 620294.6446         1
# 922675.7177         1
# 704171.5018         1
# 528847.5626         1
# 661231.6305         1
# Name: last_rech_date_da, Length: 1174, dtype: int64

# %%
sns.violinplot(x="maxamnt_loans30",data=df,palette="terrain_r")
plt.title("maximum amount of loan taken by the user in last 30 days",fontsize=18)
plt.show()
print(df["maxamnt_loans30"].value_counts())
# Out:
# 6.00000        179193
# 12.00000        26109
# 0.00000          3244
# 81942.46706         1
# 37924.22565         1
#                 ...
# 59009.78440         1
# 37974.06964         1
# 32677.26348         1
# 80242.80113         1
# 79476.60127         1
# Name: maxamnt_loans30, Length: 1050, dtype: int64

# %% [raw]
# Observation:
#     The maximum amount of loan taken by user in last 30 days is 179193.

# %%
sns.violinplot(x="medianamnt_loans30",data=df,palette="gist_earth")
plt.title("Median of amounts of loan taken by the user in last 30 days",fontsize=18)
plt.show()
print(df["medianamnt_loans30"].value_counts())
# Out:
# 0.0    195445
# 1.0      7149
# 0.5      6538
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64

# %% [raw]
# Observation:
#     Median of amounts of loan taken by the user in last 30 days is 195445.

# %%
sns.violinplot(x="cnt_loans90",data=df,palette="cool")
plt.title("Number of loans taken by user in last 90 days",fontsize=18)
plt.show()
print(df["cnt_loans90"].value_counts())
# Out:
# 1.000000       73862
# 2.000000       37286
# 3.000000       23986
# 4.000000       16761
# 5.000000       12331
#                ...
# 2869.580125        1
# 2218.225624        1
# 3096.002080        1
# 2893.258858        1
# 3479.417395        1
# Name: cnt_loans90, Length: 1110, dtype: int64

# %% [raw]
# Observation:
#           73862 Number of loan taken by user in last 90 days

# %%
sns.countplot(x="amnt_loans90",data=df,palette="gist_ncar_r")
plt.title("Total amount of loans taken by user in last 90 days",fontsize=18)
plt.show()
print(df["amnt_loans90"].value_counts())
# Out:
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 360        1
# 426        1
# 396        1
# 438        1
# 342        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %% [raw]
# Observation:
#     Total amount of loans taken by users in last 90 days is 69131.

# %%
sns.countplot(x="maxamnt_loans90",data=df,palette="prism")
plt.title("maximum amount of loan taken by the user in last 90 days",fontsize=18)
plt.show()
print(df["maxamnt_loans90"].value_counts())
print(df["maxamnt_loans90"].unique())
# Out:
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64
# [ 6 12  0]

# %% [raw]
# observation:
#     There is 3 categories maximum loan taken by user in last 90 days under 6 is 180945,under 12 is 26605,and under 0 is 2043.

# %%
sns.violinplot(x="medianamnt_loans90",data=df,palette="flag")
plt.title("Median of amounts of loan taken by the user in last 90 days",fontsize=18)
plt.show()
print(df["medianamnt_loans90"].value_counts())
print(df["medianamnt_loans90"].unique())
# Out:
# 0.0    197424
# 1.0      6172
# 0.5      5668
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64
# [0.  1.  0.5 2.  1.5 3. ]

# %% [raw]
# Observation:
#     The median of amounts of loan taken by user in last 90 days in 0.0 197424 1.0 is 6172 and 0.5 is 5668.

# %%
sns.scatterplot(x="payback30",y="pdate",data=df,palette="tab10")
plt.title("Average payback time in days over last 30 days",fontsize=18)
plt.xlabel("date and average paybacktime")
plt.xticks(rotation="vertical")
plt.show()
print(df["payback30"].value_counts())
print(df["payback30"].unique())
# Out:
# 0.000000      106712
# 2.000000        5601
# 3.000000        5023
# 4.000000        3931
# 2.500000        3518
#                ...
# 26.200000          1
# 1.351351           1
# 21.400000          1
# 105.666667         1
# 5.272727           1
# Name: payback30, Length: 1363, dtype: int64
# [29.          0.          2.33333333 ... 56.75       64.33333333
#   5.61538461]

# %%
sns.scatterplot(x="payback90",y="pdate",data=df,palette="coolwarm")
plt.title("Average payback time in days over last 90 days",fontsize=18)
plt.xlabel("date and average payback time in days over last 90 days",fontsize=18)
plt.xticks(rotation="vertical")
plt.show()
print(df["payback90"].value_counts())
print(df["payback90"].unique())
# Out:
# 0.000000     95699
# 2.000000      4982
# 3.000000      4437
# 4.000000      3610
# 2.500000      3015
#              ...
# 3.148148         1
# 88.333333        1
# 25.222222        1
# 29.600000        1
# 31.600000        1
# Name: payback90, Length: 2381, dtype: int64
# [29.          0.          2.33333333 ... 64.33333333  5.23529412
#  25.84615385]

# %% [markdown]
# # Bivariate Analysis

# %%
facet=sns.FacetGrid(df,col="label")
facet.map(sns.distplot,"amnt_loans30")
plt.show()

# %%
plt.figure(figsize=(20,14))
sns.countplot(x="maxamnt_loans90",hue="label",data=df,palette="cool")
plt.title("Dafaulter and Non-Dafaulter according total amount of loan taken by user in last 30 days",fontsize=18)
plt.xlabel("0 and 1")
plt.ylabel("count")
plt.show()
print(df.groupby("maxamnt_loans90")["label"].value_counts())
# Out:
# maxamnt_loans90  label
# 0                1          2043
# 6                1        155805
#                  0         25140
# 12               1         25583
#                  0          1022
# Name: label, dtype: int64

# %% [raw]
# Observation:
#          26,162 users are defaulter and  183,431  users has payed the loans.

# %%
plt.figure(figsize=(20,14))
sns.scatterplot(x="label",y="amnt_loans90",data=df,palette="cool")
plt.title("Dafaulter and Non-Dafaulter according total amount of loan taken by users in last 90 days",fontsize=18)
plt.xlabel("0 and 1")
plt.ylabel("count")
plt.show()
print(df.groupby("label")["amnt_loans90"].value_counts())
# Out:
# label  amnt_loans90
# 0      6               18847
#        12               3967
#        18               1535
#        24                743
#        30                412
#                        ...
# 1      372                 1
#        396                 1
#        402                 1
#        426                 1
#        438                 1
# Name: amnt_loans90, Length: 95, dtype: int64

# %% [raw]
# Observation:
#     The Deafaulter has taken total 25504 loans in 90 days.

# %% [raw]
# i will drop unnmaed,pcirclr,pdata and msisdn which do not provide any information about data set.

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %% [markdown]
# # Data cleaning

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.drop("pcircle",axis=1,inplace=True)

# %%
df.drop("pdate",axis=1,inplace=True)

# %%
df.drop("msisdn",axis=1,inplace=True)

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %% [raw]
# As of now i have done visiulization so i have find 998650 and 999171 which is not realstic data,so i wiil drop the column,

# %%
df.drop(["last_rech_date_ma",'last_rech_date_da'],axis=1,inplace=True)

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# ...

# %% [raw]
# Observation:
#     I will drop payback30 and  payback90 as they are unrealistic values present in data set.

# %%
df.drop(["payback30","payback90"],axis=1,inplace=True)

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# ...

# %%
df.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90'],
#       dtype='object')

# %%
df.drop(['cnt_loans90',"amnt_loans90"],axis=1,inplace=True)

# %%
df.drop(["maxamnt_loans30","medianamnt_loans30","cnt_da_rech90"],axis=1,inplace=True)

# %%
df.drop(['fr_da_rech30', 'cnt_loans30',],axis=1,inplace=True)

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  ...  \
# 0              1539              2          21.0             3078.0  ...
# 1              5787              1           0.0             5787.0  ...
# 2              1539              1           0.0             1539.0  ...
# 3               947              0           0.0                0.0  ...
# 4              2309              7           2.0            20029.0  ...
#
#    cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# ...

# %% [raw]
# Observation:
#     As of now i have drop all the unrealistic data from the data set.

# %% [markdown]
# # Plotting Outliers:

# %%
df.plot(kind="box",subplots=True,layout=(2,11))
# Out:
# label                      AxesSubplot(0.125,0.536818;0.0596154x0.343182)
# aon                     AxesSubplot(0.196538,0.536818;0.0596154x0.343182)
# daily_decr30            AxesSubplot(0.268077,0.536818;0.0596154x0.343182)
# daily_decr90            AxesSubplot(0.339615,0.536818;0.0596154x0.343182)
# rental30                AxesSubplot(0.411154,0.536818;0.0596154x0.343182)
# rental90                AxesSubplot(0.482692,0.536818;0.0596154x0.343182)
# last_rech_amt_ma        AxesSubplot(0.554231,0.536818;0.0596154x0.343182)
# cnt_ma_rech30           AxesSubplot(0.625769,0.536818;0.0596154x0.343182)
# fr_ma_rech30            AxesSubplot(0.697308,0.536818;0.0596154x0.343182)
# sumamnt_ma_rech30       AxesSubplot(0.768846,0.536818;0.0596154x0.343182)
# medianamnt_ma_rech30    AxesSubplot(0.840385,0.536818;0.0596154x0.343182)
# medianmarechprebal30          AxesSubplot(0.125,0.125;0.0596154x0.343182)
# cnt_ma_rech90              AxesSubplot(0.196538,0.125;0.0596154x0.343182)
# ...

# %% [raw]
# Observation:
#     There are outliers present in data set.so i have to remove it.

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     30, ..., 209580, 209581, 209587], dtype=int32), array([13, 13, 21, ..., 20,  3, 21], dtype=int32))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print(df_new.shape)
print(df.shape)
# Out:
# (171618, 22)
# (209593, 22)

# %%
Percentloss=(209593-170220)/209593*100

# %%
Percentloss
# Out:
# 18.785455621132385

# %% [raw]
# As we are loosing so much of data i will go with outliers,bec we cannot loose more than 8 to 9% of data .

# %% [markdown]
# # Checking Skewness

# %%
for col in df.describe().columns:
    sns.distplot(df[col],color="b")
    plt.show()

# %% [raw]
# Observation:
#     Skewness present in data so we have remove it.

# %% [markdown]
# # Feature Selection

# %%
x=df.drop(columns=["label"],axis=1)
y=df["label"]

# %%
x
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 209588   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 0                   1539              2          21.0             3078.0
# ...

# %%
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %% [markdown]
# # Removing Skewness

# %%
#Importing library
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method="yeo-johnson")
print(x)
# Out:
# [[-0.17711186  0.332156    0.29918138 ... -0.09756296 -0.28561065
#   -0.24827185]
#  [ 0.03645291  1.11602076  1.04508396 ... -0.09756296  2.32582829
#   -0.24827185]
#  [-0.03465905 -0.00750823 -0.02820273 ... -0.89478225 -0.28561065
#   -0.24827185]
#  ...
#  [ 0.13457681  1.10045475  1.03342362 ...  1.45495146  2.32582829
#   -0.24827185]
#  [ 0.30910144  1.13605673  1.06838078 ...  0.39323559  2.32582829
#   -0.24827185]
#  [ 0.27706283  0.52502128  0.48715657 ...  0.39323559  2.32582829
#   -0.24827185]]

# %% [markdown]
# # Normalizing data

# %%
#Importing Library
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.17711186,  0.332156  ,  0.29918138, ..., -0.09756296,
#         -0.28561065, -0.24827185],
#        [ 0.03645291,  1.11602076,  1.04508396, ..., -0.09756296,
#          2.32582829, -0.24827185],
#        [-0.03465905, -0.00750823, -0.02820273, ..., -0.89478225,
#         -0.28561065, -0.24827185],
#        ...,
#        [ 0.13457681,  1.10045475,  1.03342362, ...,  1.45495146,
#          2.32582829, -0.24827185],
#        [ 0.30910144,  1.13605673,  1.06838078, ...,  0.39323559,
#          2.32582829, -0.24827185],
#        [ 0.27706283,  0.52502128,  0.48715657, ...,  0.39323559,
#          2.32582829, -0.24827185]])

# %% [markdown]
# # Building Machine Learning Model

# %%
#spitting the data into training and testing 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=42,stratify=y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (28499, 21)
# (4930, 21)
# (28499,)
# (4930,)

# %%
#importing all the model library
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
#Importing Boosting Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
#All algorithm using loop
model=[LogisticRegression(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier(),
      RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier()]
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print("Accuracy Score of",m,"is:")
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print("***************************************************************************************************")
    print("\n")
# Out:
# Accuracy Score of LogisticRegression() is:
# 0.5929006085192697
# [[   0    0]
#  [2007 2923]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.59      0.74      4930
#
#     accuracy                           0.59      4930
#    macro avg       0.50      0.30      0.37      4930
# weighted avg       1.00      0.59      0.74      4930
#
# ***************************************************************************************************
#
#
# Accuracy Score of SVC() is:
# 0.5993914807302231
# [[   0    0]
#  [1975 2955]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.60      0.75      4930
#
#     accuracy                           0.60      4930
#    macro avg       0.50      0.30      0.37      4930
# weighted avg       1.00      0.60      0.75      4930
#
# ...

# %%
#cross validation the model
cvscore=cross_val_score(LogisticRegression(),x,y,cv=2,scoring="accuracy")
print(cvscore)
print("Mean:",cvscore.mean())
print("Standard Deviation:",cvscore.std())
# Out:
# [0.88383255 0.88215199]
# Mean: 0.8829922714962763
# Standard Deviation: 0.0008402809622864438

# %%
cvscore=cross_val_score(DecisionTreeClassifier(),x,y,cv=2,scoring="accuracy")
print(cvscore)
print("Mean:",cvscore.mean())
print("Standard Deviation",cvscore.std())
# Out:
# [0.86173268 0.86088209]
# Mean: 0.861307388961968
# Standard Deviation 0.0004252942255277836

# %%
cvscore=cross_val_score(RandomForestClassifier(),x,y,cv=2,scoring="accuracy")
print(cvscore)
print("Mean:",cvscore.mean())
print("Standard Deviation:",cvscore.std())
# Out:
# [0.90964436 0.91075041]
# Mean: 0.9101973851847396
# Standard Deviation: 0.0005530251362649286

# %%
cvscore=cross_val_score(GradientBoostingClassifier(),x,y,cv=2,scoring="accuracy")
print(cvscore)
print("Mean:",cvscore.mean())
print("Standard Deviation:",cvscore.std())
# Out:
# [0.90882373 0.90920455]
# Mean: 0.9090141378309962
# Standard Deviation: 0.0001904119609807409

# %% [markdown]
# # Using GridSearchCV to find out the best parameter

# %%
#Using GridSearchcv to find out best parameter in logisticregression
parameters={"C":[1,10],"random_state":range(42,56)}
lg=LogisticRegression()
clf=GridSearchCV(lg,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'C': 10, 'random_state': 48}

# %%
#using GridSearchCV to find the best parameter in decisionTreeclassifier
parameters={"criterion":["giny","entropy"],"random_state":range(42,60)}
dtc=DecisionTreeClassifier()
clf=GridSearchCV(dtc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'random_state': 42}

# %% [markdown]
# # LogisticRegression

# %%
lg=LogisticRegression(C=10,random_state=48)
lg.fit(x_train,y_train)
predlg=lg.predict(x_test)
print(accuracy_score(y_test,predlg))
print(confusion_matrix(y_test,predlg))
print(classification_report(y_test,predlg))
# Out:
# 0.5908722109533469
# [[   0    0]
#  [2017 2913]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.59      0.74      4930
#
#     accuracy                           0.59      4930
#    macro avg       0.50      0.30      0.37      4930
# weighted avg       1.00      0.59      0.74      4930

# %%
predlg_proba=lg.predict_proba(x_test)[:,1]
fpr,tpr,threshold=roc_curve(y_test,predlg)
plt.plot([0,1],[0,1],  'k--')
plt.plot(fpr,tpr,label='LogisticRegression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LogisticRegression')
plt.show()

# %% [markdown]
# # DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier(criterion="entropy",random_state=42)
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
predtc=dtc.predict(x_test)
print(accuracy_score(y_test,predtc))
print(confusion_matrix(y_test,predtc))
print(classification_report(y_test,predtc))
# Out:
# 0.6425963488843813
# [[   0    0]
#  [1762 3168]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.64      0.78      4930
#
#     accuracy                           0.64      4930
#    macro avg       0.50      0.32      0.39      4930
# weighted avg       1.00      0.64      0.78      4930

# %%
predtc_proba=dtc.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,predtc)
plt.plot([0,1],[0,1])
plt.plot(fpr,tpr,label='DecisionTreeClassifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("DecisionTreeClassifier")
plt.show()

# %% [markdown]
# # RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=200)
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.6941176470588235
# [[   0    0]
#  [1508 3422]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.69      0.82      4930
#
#     accuracy                           0.69      4930
#    macro avg       0.50      0.35      0.41      4930
# weighted avg       1.00      0.69      0.82      4930

# %%
predrfc_proba=rfc.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,predrfc)
plt.plot([0,1],[0,1])
plt.plot(fpr,tpr,label='RandomForestClassifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("RandomForestClassifier")
plt.show()

# %% [raw]
# Observation:
#     RandomForestClassifier gives the best score amoungs all the algorithms as well in crossvaildationscore,so i m finaling the     model with RandomForestClassifier.

# %% [markdown]
# # Conclusion:

# %%
a=np.array(y_test)

# %%
Prediction=np.array(rfc.predict(x_test))

# %%
df_new=pd.DataFrame({"Original_Micro":a,"Prediction_Micro":Prediction},index=range(len(a)))

# %%
df_new
# Out:
#       Original_Micro  Prediction_Micro
# 0                  1                 0
# 1                  1                 1
# 2                  1                 1
# 3                  1                 1
# 4                  1                 1
# ...              ...               ...
# 4925               1                 1
# 4926               1                 1
# 4927               1                 0
# 4928               1                 1
# 4929               1                 1
#
# [4930 rows x 2 columns]
